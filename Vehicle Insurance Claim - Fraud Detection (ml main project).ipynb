# %%
#we are import all the libraries to analysize the data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_auc_score
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
df=pd.read_csv(r"C:\Users\cheta_us3mss3\Downloads\fraud_oracle.csv")
df.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Jan            5     Monday   Honda        Urban          Tuesday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  AgeOfVehicle  \
# 0          Jan                   1  Female        Single  ...       3 years
# 1          Jan                   4    Male        Single  ...       6 years
# 2          Nov                   2    Male       Married  ...       7 years
# 3          Jul                   1    Male       Married  ...   more than 7
# 4          Feb                   2  Female        Single  ...       5 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15420 entries, 0 to 15419
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 15420 non-null  object
#  1   WeekOfMonth           15420 non-null  int64
#  2   DayOfWeek             15420 non-null  object
#  3   Make                  15420 non-null  object
#  4   AccidentArea          15420 non-null  object
#  5   DayOfWeekClaimed      15420 non-null  object
#  6   MonthClaimed          15420 non-null  object
#  7   WeekOfMonthClaimed    15420 non-null  int64
#  8   Sex                   15420 non-null  object
#  9   MaritalStatus         15420 non-null  object
#  10  Age                   15420 non-null  int64
#  11  Fault                 15420 non-null  object
#  12  PolicyType            15420 non-null  object
#  13  VehicleCategory       15420 non-null  object
#  14  VehiclePrice          15420 non-null  object
# ...

# %%
df.shape
# Out:
# (15420, 33)

# %%
df.describe()
# Out:
#         WeekOfMonth  WeekOfMonthClaimed           Age  FraudFound_P  \
# count  15420.000000        15420.000000  15420.000000  15420.000000
# mean       2.788586            2.693969     39.855707      0.059857
# std        1.287585            1.259115     13.492377      0.237230
# min        1.000000            1.000000      0.000000      0.000000
# 25%        2.000000            2.000000     31.000000      0.000000
# 50%        3.000000            3.000000     38.000000      0.000000
# 75%        4.000000            4.000000     48.000000      0.000000
# max        5.000000            5.000000     80.000000      1.000000
#
#        PolicyNumber     RepNumber    Deductible  DriverRating          Year
# count  15420.000000  15420.000000  15420.000000  15420.000000  15420.000000
# mean    7710.500000      8.483268    407.704280      2.487808   1994.866472
# std     4451.514911      4.599948     43.950998      1.119453      0.803313
# ...

# %%
df.isnull().sum()
# Out:
# Month                   0
# WeekOfMonth             0
# DayOfWeek               0
# Make                    0
# AccidentArea            0
# DayOfWeekClaimed        0
# MonthClaimed            0
# WeekOfMonthClaimed      0
# Sex                     0
# MaritalStatus           0
# Age                     0
# Fault                   0
# PolicyType              0
# VehicleCategory         0
# VehiclePrice            0
# FraudFound_P            0
# PolicyNumber            0
# RepNumber               0
# Deductible              0
# DriverRating            0
# Days_Policy_Accident    0
# Days_Policy_Claim       0
# PastNumberOfClaims      0
# AgeOfVehicle            0
# AgeOfPolicyHolder       0
# PoliceReportFiled       0
# WitnessPresent          0
# AgentType               0
# NumberOfSuppliments     0
# AddressChange_Claim     0
# NumberOfCars            0
# Year                    0
# BasePolicy              0
# dtype: int64

# %%
df.corr()
# Out:
#                     WeekOfMonth  WeekOfMonthClaimed       Age  FraudFound_P  \
# WeekOfMonth            1.000000            0.275400 -0.004810     -0.011861
# WeekOfMonthClaimed     0.275400            1.000000  0.001859     -0.005761
# Age                   -0.004810            0.001859  1.000000     -0.029741
# FraudFound_P          -0.011861           -0.005761 -0.029741      1.000000
# PolicyNumber          -0.007797            0.011665  0.025944     -0.020345
# RepNumber              0.005283            0.008908 -0.007063     -0.007551
# Deductible            -0.003993            0.005457  0.069420      0.017348
# DriverRating          -0.016817           -0.000048  0.001668      0.007266
# Year                  -0.003906            0.012175  0.025197     -0.024760
#
#                     PolicyNumber  RepNumber  Deductible  DriverRating  \
# WeekOfMonth            -0.007797   0.005283   -0.003993     -0.016817
# ...

# %%
df.shape
# Out:
# (15420, 33)

# %%
df["FraudFound_P"].value_counts()
# Out:
# 0    14497
# 1      923
# Name: FraudFound_P, dtype: int64

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue="FraudFound_P")

# %%
catcol=df.select_dtypes(object).columns
catcol
# Out:
# Index(['Month', 'DayOfWeek', 'Make', 'AccidentArea', 'DayOfWeekClaimed',
#        'MonthClaimed', 'Sex', 'MaritalStatus', 'Fault', 'PolicyType',
#        'VehicleCategory', 'VehiclePrice', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType',
#        'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars',
#        'BasePolicy'],
#       dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
df[catcol]=oe.fit_transform(df[catcol])

# %%
for col in df:
    sns.boxplot(data=df,x="FraudFound_P",y=col)
    plt.show()

# %%
x=df.iloc[:,:-1]
x
# Out:
#        Month  WeekOfMonth  DayOfWeek  Make  AccidentArea  DayOfWeekClaimed  \
# 0        2.0            5        6.0   6.0           1.0               6.0
# 1        4.0            3        6.0   6.0           1.0               2.0
# 2       10.0            5        0.0   6.0           1.0               5.0
# 3        6.0            2        2.0  17.0           0.0               1.0
# 4        4.0            5        1.0   6.0           1.0               6.0
# ...      ...          ...        ...   ...           ...               ...
# 15415    9.0            4        0.0  17.0           1.0               6.0
# 15416    9.0            5        4.0  13.0           1.0               1.0
# 15417    9.0            5        4.0  17.0           0.0               1.0
# 15418    2.0            1        1.0  17.0           1.0               5.0
# 15419    2.0            2        6.0  17.0           1.0               5.0
#
#        MonthClaimed  WeekOfMonthClaimed  Sex  MaritalStatus  ...  \
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#           Month  WeekOfMonth  DayOfWeek      Make  AccidentArea  \
# 0      1.035963     1.717545   1.500542  0.778873      0.340019
# 1      0.449364     0.164199   1.500542  0.778873      0.340019
# 2      1.310432     1.717545   1.418572  0.778873      0.340019
# 3      0.137234     0.612473   0.445534  1.303376      2.941014
# 4      0.449364     1.717545   0.932053  0.778873      0.340019
# ...         ...          ...        ...       ...           ...
# 15415  1.017133     0.940872   1.418572  1.303376      0.340019
# 15416  1.017133     1.717545   0.527504  0.546195      0.340019
# 15417  1.017133     1.717545   0.527504  1.303376      2.941014
# 15418  1.035963     1.389146   0.932053  1.303376      0.340019
# 15419  1.035963     0.612473   1.500542  1.303376      0.340019
#
#        DayOfWeekClaimed  MonthClaimed  WeekOfMonthClaimed       Sex  \
# 0              0.790376      0.467838            1.345408  2.317736
# ...

# %%
newdf=df[(z<3).all(axis=1)]
newdf
# Out:
#        Month  WeekOfMonth  DayOfWeek  Make  AccidentArea  DayOfWeekClaimed  \
# 2       10.0            5        0.0   6.0           1.0               5.0
# 4        4.0            5        1.0   6.0           1.0               6.0
# 5       10.0            4        0.0   6.0           1.0               7.0
# 6        3.0            1        2.0   6.0           1.0               2.0
# 10       7.0            2        3.0   9.0           1.0               7.0
# ...      ...          ...        ...   ...           ...               ...
# 15403    9.0            2        3.0  13.0           1.0               2.0
# 15406    9.0            3        6.0   5.0           1.0               1.0
# 15410    9.0            3        3.0   3.0           1.0               6.0
# 15411    9.0            4        5.0   6.0           0.0               7.0
# 15414    9.0            4        0.0   2.0           1.0               2.0
#
#        MonthClaimed  WeekOfMonthClaimed  Sex  MaritalStatus  ...  \
# ...

# %%
newdf.shape
# Out:
# (11925, 33)

# %%
x=newdf.iloc[:,:-1]
x
# Out:
#        Month  WeekOfMonth  DayOfWeek  Make  AccidentArea  DayOfWeekClaimed  \
# 2       10.0            5        0.0   6.0           1.0               5.0
# 4        4.0            5        1.0   6.0           1.0               6.0
# 5       10.0            4        0.0   6.0           1.0               7.0
# 6        3.0            1        2.0   6.0           1.0               2.0
# 10       7.0            2        3.0   9.0           1.0               7.0
# ...      ...          ...        ...   ...           ...               ...
# 15403    9.0            2        3.0  13.0           1.0               2.0
# 15406    9.0            3        6.0   5.0           1.0               1.0
# 15410    9.0            3        3.0   3.0           1.0               6.0
# 15411    9.0            4        5.0   6.0           0.0               7.0
# 15414    9.0            4        0.0   2.0           1.0               2.0
#
#        MonthClaimed  WeekOfMonthClaimed  Sex  MaritalStatus  ...  \
# ...

# %%
newdf.skew()
# Out:
# Month                  -0.025053
# WeekOfMonth             0.110854
# DayOfWeek               0.043800
# Make                   -0.241648
# AccidentArea           -2.696036
# DayOfWeekClaimed       -0.206353
# MonthClaimed           -0.052428
# WeekOfMonthClaimed      0.157938
# Sex                    -1.823129
# MaritalStatus           0.821268
# Age                     0.758208
# Fault                   0.916870
# PolicyType              0.413893
# VehicleCategory         0.540918
# VehiclePrice            1.469082
# FraudFound_P            0.000000
# PolicyNumber           -0.001630
# RepNumber               0.010164
# Deductible              0.000000
# DriverRating            0.025254
# Days_Policy_Accident    0.000000
# Days_Policy_Claim       0.000000
# PastNumberOfClaims      0.208073
# AgeOfVehicle           -0.509437
# AgeOfPolicyHolder       0.624605
# PoliceReportFiled       0.000000
# WitnessPresent          0.000000
# AgentType               0.000000
# ...

# %%
y=newdf.iloc[:,14]
y
# Out:
# 2        5.0
# 4        5.0
# 5        5.0
# 6        5.0
# 10       5.0
#         ...
# 15403    0.0
# 15406    3.0
# 15410    0.0
# 15411    4.0
# 15414    1.0
# Name: VehiclePrice, Length: 11925, dtype: float64

# %%
colname=x.select_dtypes(["int64","float64"]).columns
colname
# Out:
# Index(['Month', 'WeekOfMonth', 'DayOfWeek', 'Make', 'AccidentArea',
#        'DayOfWeekClaimed', 'MonthClaimed', 'WeekOfMonthClaimed', 'Sex',
#        'MaritalStatus', 'Age', 'Fault', 'PolicyType', 'VehicleCategory',
#        'VehiclePrice', 'FraudFound_P', 'PolicyNumber', 'RepNumber',
#        'Deductible', 'DriverRating', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType',
#        'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'Year'],
#       dtype='object')

# %%
from scipy.stats import skew

# %%
for i in x[colname]:
    print(i)
    print(skew(x[i]))
    plt.figure()
    sns.distplot(x[i])
    plt.show()
# Out:
# Month
# -0.025050268339155107
# WeekOfMonth
# 0.1108402950315276
# DayOfWeek
# 0.04379456760554553
# Make
# -0.2416175755715263
# AccidentArea
# -2.6956965823692967
# DayOfWeekClaimed
# -0.20632734475294015
# MonthClaimed
# -0.052421535065672764
# WeekOfMonthClaimed
# 0.15791802124158824
# Sex
# -1.8228999695611106
# MaritalStatus
# 0.8211648958151428
# Age
# 0.7581125912528948
# Fault
# 0.9167543108548082
# PolicyType
# 0.4138410102714947
# VehicleCategory
# 0.5408499972834668
# VehiclePrice
# 1.46889720043356
# FraudFound_P
# 0.0
# PolicyNumber
# -0.001629969716445007
# RepNumber
# 0.010162886877649336
# Deductible
# 0.0
# DriverRating
# 0.025250438485182564
# Days_Policy_Accident
# 0.0
# Days_Policy_Claim
# 0.0
# PastNumberOfClaims
# 0.20804636592576595
# AgeOfVehicle
# -0.509373314182851
# AgeOfPolicyHolder
# 0.6245269179584028
# PoliceReportFiled
# 0.0
# WitnessPresent
# 0.0
# AgentType
# 0.0
# NumberOfSuppliments
# -0.6733549372586431
# AddressChange_Claim
# ...

# %%
plt.figure(figsize=(35,38))
sns.heatmap(x.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
def mymodel(model):
    model.fit(xtrain,ytrain)
    ypred=model.predict(xtest)
    
    train=model.score(xtrain,ytrain)
    test=model.score(xtest,ytest)
    
    print(f"Training accuracy:{train}\nTesting score:{test}")
    print(classification_report(ytest,ypred))
    
    return model

# %%
#lr=mymodel(LinearRegression())

# %%
log=mymodel(LogisticRegression())
# Out:
# Training accuracy:0.5625973403618066
# Testing score:0.5441587479038569
#               precision    recall  f1-score   support
#
#          0.0       0.54      1.00      0.70      1947
#          1.0       0.00      0.00      0.00       861
#          2.0       0.00      0.00      0.00        95
#          3.0       0.00      0.00      0.00        24
#          4.0       0.00      0.00      0.00       277
#          5.0       0.00      0.00      0.00       374
#
#     accuracy                           0.54      3578
#    macro avg       0.09      0.17      0.12      3578
# weighted avg       0.30      0.54      0.38      3578

# %%
parameters={'C':[0.7,0.9,0.5,0.4]}

# %%
from sklearn.model_selection import GridSearchCV
grid=GridSearchCV(LogisticRegression(),parameters)
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'C': [0.7, 0.9, 0.5, 0.4]})

# %%
grid.best_params_
# Out:
# {'C': 0.4}

# %%
log=mymodel(grid.best_estimator_)
# Out:
# Training accuracy:0.5625973403618066
# Testing score:0.5441587479038569
#               precision    recall  f1-score   support
#
#          0.0       0.54      1.00      0.70      1947
#          1.0       0.00      0.00      0.00       861
#          2.0       0.00      0.00      0.00        95
#          3.0       0.00      0.00      0.00        24
#          4.0       0.00      0.00      0.00       277
#          5.0       0.00      0.00      0.00       374
#
#     accuracy                           0.54      3578
#    macro avg       0.09      0.17      0.12      3578
# weighted avg       0.30      0.54      0.38      3578

# %%
dt=mymodel(DecisionTreeClassifier())
# Out:
# Training accuracy:1.0
# Testing score:1.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1947
#          1.0       1.00      1.00      1.00       861
#          2.0       1.00      1.00      1.00        95
#          3.0       1.00      1.00      1.00        24
#          4.0       1.00      1.00      1.00       277
#          5.0       1.00      1.00      1.00       374
#
#     accuracy                           1.00      3578
#    macro avg       1.00      1.00      1.00      3578
# weighted avg       1.00      1.00      1.00      3578

# %%
parameters={"criterion":["gini","entropy"],
           "max_depth":list(range(50,100,2)),
           "min_samples_leaf":list(range(50,100,2))}

# %%
grid=GridSearchCV(DecisionTreeClassifier(),parameters)
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [50, 52, 54, 56, 58, 60, 62, 64, 66, 68,
#                                        70, 72, 74, 76, 78, 80, 82, 84, 86, 88,
#                                        90, 92, 94, 96, 98],
#                          'min_samples_leaf': [50, 52, 54, 56, 58, 60, 62, 64,
#                                               66, 68, 70, 72, 74, 76, 78, 80,
#                                               82, 84, 86, 88, 90, 92, 94, 96,
#                                               98]})

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 50, 'min_samples_leaf': 50}

# %%
dt=mymodel(grid.best_estimator_)
# Out:
# Training accuracy:0.9944890379777166
# Testing score:0.9932923420905534
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1947
#          1.0       1.00      1.00      1.00       861
#          2.0       0.80      1.00      0.89        95
#          3.0       0.00      0.00      0.00        24
#          4.0       1.00      1.00      1.00       277
#          5.0       1.00      1.00      1.00       374
#
#     accuracy                           0.99      3578
#    macro avg       0.80      0.83      0.81      3578
# weighted avg       0.99      0.99      0.99      3578

# %%
knn=mymodel(KNeighborsClassifier())
# Out:
# Training accuracy:0.6211812627291242
# Testing score:0.5106204583566238
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.86      0.68      1947
#          1.0       0.28      0.15      0.19       861
#          2.0       0.12      0.01      0.02        95
#          3.0       0.00      0.00      0.00        24
#          4.0       0.13      0.01      0.03       277
#          5.0       0.18      0.02      0.04       374
#
#     accuracy                           0.51      3578
#    macro avg       0.21      0.18      0.16      3578
# weighted avg       0.40      0.51      0.42      3578

# %%
knn = KNeighborsClassifier()
from sklearn.model_selection import GridSearchCV
k_range = list(range(100,200))
param_grid = dict(n_neighbors=k_range)
  
# defining parameter range
grid = GridSearchCV(knn, param_grid, cv=10, scoring='accuracy', return_train_score=False,verbose=1)
  
# fitting the model for grid search
grid_search=grid.fit(xtrain, ytrain)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits

# %%
grid.best_params_
# Out:
# {'n_neighbors': 100}

# %%
knn=mymodel(grid.best_estimator_)
# Out:
# Training accuracy:0.5625973403618066
# Testing score:0.5441587479038569
#               precision    recall  f1-score   support
#
#          0.0       0.54      1.00      0.70      1947
#          1.0       0.00      0.00      0.00       861
#          2.0       0.00      0.00      0.00        95
#          3.0       0.00      0.00      0.00        24
#          4.0       0.00      0.00      0.00       277
#          5.0       0.00      0.00      0.00       374
#
#     accuracy                           0.54      3578
#    macro avg       0.09      0.17      0.12      3578
# weighted avg       0.30      0.54      0.38      3578

# %%
rm=mymodel(RandomForestClassifier())
# Out:
# Training accuracy:1.0
# Testing score:0.9863051984348798
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1947
#          1.0       1.00      1.00      1.00       861
#          2.0       0.83      0.87      0.85        95
#          3.0       0.00      0.00      0.00        24
#          4.0       0.93      0.97      0.95       277
#          5.0       0.98      0.99      0.98       374
#
#     accuracy                           0.99      3578
#    macro avg       0.79      0.81      0.80      3578
# weighted avg       0.98      0.99      0.98      3578

# %%
param_grid = {'max_depth':range(2,7),'n_estimators':range(10,30)}

# %%
grid=GridSearchCV(RandomForestClassifier(),param_grid)
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': range(2, 7),
#                          'n_estimators': range(10, 30)})

# %%
grid.best_params_
# Out:
# {'max_depth': 6, 'n_estimators': 17}

# %%
rm=mymodel(grid.best_estimator_)
# Out:
# Training accuracy:0.9457290044327303
# Testing score:0.9385131358300727
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1947
#          1.0       0.90      1.00      0.95       861
#          2.0       1.00      0.03      0.06        95
#          3.0       0.00      0.00      0.00        24
#          4.0       0.88      0.74      0.81       277
#          5.0       0.80      0.91      0.85       374
#
#     accuracy                           0.94      3578
#    macro avg       0.76      0.61      0.61      3578
# weighted avg       0.94      0.94      0.92      3578

# %%
ab=mymodel(AdaBoostClassifier())
# Out:
# Training accuracy:0.898047202587756
# Testing score:0.8893236444941308
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1947
#          1.0       0.68      1.00      0.81       861
#          2.0       0.00      0.00      0.00        95
#          3.0       0.00      0.00      0.00        24
#          4.0       0.00      0.00      0.00       277
#          5.0       1.00      1.00      1.00       374
#
#     accuracy                           0.89      3578
#    macro avg       0.45      0.50      0.47      3578
# weighted avg       0.81      0.89      0.84      3578

# %%
parameters={'n_estimators':range(1,100)}

# %%
grid=GridSearchCV(AdaBoostClassifier(),parameters)
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=AdaBoostClassifier(),
#              param_grid={'n_estimators': range(1, 100)})

# %%
grid.best_params_
# Out:
# {'n_estimators': 2}

# %%
ab=mymodel(grid.best_estimator_)
# Out:
# Training accuracy:0.898047202587756
# Testing score:0.8893236444941308
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1947
#          1.0       0.68      1.00      0.81       861
#          2.0       0.00      0.00      0.00        95
#          3.0       0.00      0.00      0.00        24
#          4.0       0.00      0.00      0.00       277
#          5.0       1.00      1.00      1.00       374
#
#     accuracy                           0.89      3578
#    macro avg       0.45      0.50      0.47      3578
# weighted avg       0.81      0.89      0.84      3578

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier

# %%
xgb=mymodel(XGBClassifier())
# Out:
# Training accuracy:1.0
# Testing score:1.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1947
#          1.0       1.00      1.00      1.00       861
#          2.0       1.00      1.00      1.00        95
#          3.0       1.00      1.00      1.00        24
#          4.0       1.00      1.00      1.00       277
#          5.0       1.00      1.00      1.00       374
#
#     accuracy                           1.00      3578
#    macro avg       1.00      1.00      1.00      3578
# weighted avg       1.00      1.00      1.00      3578

# %%
parameters={'reg_alpha':range(1,200)}

# %%
grid=GridSearchCV(XGBClassifier(),parameters)
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
# ...

# %%
grid.best_params_
# Out:
# {'reg_alpha': 1}

# %%
xgb=mymodel(grid.best_estimator_)
# Out:
# Training accuracy:1.0
# Testing score:1.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1947
#          1.0       1.00      1.00      1.00       861
#          2.0       1.00      1.00      1.00        95
#          3.0       1.00      1.00      1.00        24
#          4.0       1.00      1.00      1.00       277
#          5.0       1.00      1.00      1.00       374
#
#     accuracy                           1.00      3578
#    macro avg       1.00      1.00      1.00      3578
# weighted avg       1.00      1.00      1.00      3578

# %%
svm=mymodel(LinearSVC())
# Out:
# Training accuracy:0.48772013897208577
# Testing score:0.48714365567356066
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.60      0.64      1947
#          1.0       0.25      0.52      0.34       861
#          2.0       0.00      0.00      0.00        95
#          3.0       0.00      0.00      0.00        24
#          4.0       0.00      0.00      0.00       277
#          5.0       1.00      0.35      0.52       374
#
#     accuracy                           0.49      3578
#    macro avg       0.32      0.24      0.25      3578
# weighted avg       0.54      0.49      0.48      3578

# %%
parameters={'random_state':[1],'C':[0.7,0.9,0.5,0.4]}

# %%
grid=GridSearchCV(LinearSVC(),parameters)
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=LinearSVC(),
#              param_grid={'C': [0.7, 0.9, 0.5, 0.4], 'random_state': [1]})

# %%
grid.best_params_
# Out:
# {'C': 0.7, 'random_state': 1}

# %%
svm=mymodel(grid.best_estimator_)
# Out:
# Training accuracy:0.5729004432730322
# Testing score:0.553661263275573
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.95      0.72      1947
#          1.0       0.24      0.10      0.14       861
#          2.0       0.00      0.00      0.00        95
#          3.0       0.00      0.00      0.00        24
#          4.0       0.18      0.01      0.03       277
#          5.0       1.00      0.12      0.21       374
#
#     accuracy                           0.55      3578
#    macro avg       0.33      0.20      0.18      3578
# weighted avg       0.50      0.55      0.45      3578

# %%
gnb=mymodel(GaussianNB())
# Out:
# Training accuracy:1.0
# Testing score:1.0
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1947
#          1.0       1.00      1.00      1.00       861
#          2.0       1.00      1.00      1.00        95
#          3.0       1.00      1.00      1.00        24
#          4.0       1.00      1.00      1.00       277
#          5.0       1.00      1.00      1.00       374
#
#     accuracy                           1.00      3578
#    macro avg       1.00      1.00      1.00      3578
# weighted avg       1.00      1.00      1.00      3578

# %%
gnb=mymodel(MultinomialNB())
# Out:
# Training accuracy:0.13621660476818018
# Testing score:0.13079932923420906
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.08      0.15      1947
#          1.0       0.83      0.05      0.09       861
#          2.0       0.03      0.44      0.05        95
#          3.0       0.09      0.04      0.06        24
#          4.0       0.54      0.05      0.10       277
#          5.0       0.12      0.55      0.20       374
#
#     accuracy                           0.13      3578
#    macro avg       0.43      0.20      0.11      3578
# weighted avg       0.80      0.13      0.14      3578

# %%
gnb=mymodel(BernoulliNB())
# Out:
# Training accuracy:0.8105906313645621
# Testing score:0.7968138624930129
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1947
#          1.0       0.60      0.84      0.70       861
#          2.0       0.00      0.00      0.00        95
#          3.0       0.00      0.00      0.00        24
#          4.0       0.43      0.64      0.51       277
#          5.0       0.00      0.00      0.00       374
#
#     accuracy                           0.80      3578
#    macro avg       0.34      0.41      0.37      3578
# weighted avg       0.72      0.80      0.75      3578
